# %%
import pandas as pd

# %%
df = pd.read_csv('../src/model/data/clean_data.csv')

# %%
df.isnull().sum()
# Out:
# movieId               0
# original_title        0
# genres                0
# actors                0
# directors             0
# overview              0
# original_language     0
# poster_path           0
# avg_rating            0
# total_rating_users    0
# popularity_score      0
# tmdbId                0
# decade                0
# dtype: int64
